# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from descriptors.acsf.sf_function import SymmetryFunction

# %%
x = np.linspace(0,8,100)
cutoff = SymmetryFunction()
plt.xlabel('Rij')
plt.ylabel('cutoff function')
plt.plot(x, [cutoff.cutoff_func2(k, 6.0) for k in
                 x])
