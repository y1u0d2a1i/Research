# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('/Users/y1u0d2/desktop/Lab/Program/python/train_test_point/learning-curve.out.csv')
data
# Out:
#     epoch  RMSEpa_Etrain_pu  RMSEpa_Etest_pu  RMSE_Etrain_pu  RMSE_Etest_pu  \
# 0       0          0.040908         0.039102        1.839003       1.742634
# 1       1          0.001315         0.001154        0.058737       0.049984
# 2       2          0.002982         0.001778        0.138619       0.078110
# 3       3          0.002227         0.001266        0.101933       0.051825
# 4       4          0.001820         0.001327        0.081471       0.055742
# 5       5          0.002874         0.000973        0.135776       0.040431
# 6       6          0.001424         0.001028        0.062662       0.041226
# 7       7          0.001281         0.001188        0.054467       0.049533
# 8       8          0.001402         0.001157        0.061255       0.048349
# 9       9          0.002156         0.001313        0.098143       0.053719
# 10     10          0.002112         0.001283        0.096475       0.053181
# ...

# %%
plt.plot(data['epoch'][5:],data['RMSE_Ftest_pu'][5:])
plt.show()
